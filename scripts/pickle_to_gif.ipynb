# %%
import pickle
import sys
import numpy as np
sys.path.append('../src')
from output import output_video, output_image

# %%
def load_data_from_pickle(f_path):
    with open(f_path, 'rb') as f:
        data = pickle.load(f)

    args = data["args"]
    non_rasterized_maps = np.array(data["non_rasterized_maps"])
    rasterized_maps = np.array(data["rasterized_maps"])
    return args, non_rasterized_maps, rasterized_maps

# %%
_, non_rasterized_maps, _ = load_data_from_pickle("../results_1ns_8080.pickle")
out_gif_path = "../1ns_8080.mp4"
output_video.output_video(non_rasterized_maps, out_gif_path, 40, 80, res_x=1000, res_y=1000, colormap_name="jet", timestamp_step=0.01, max_frames=240,
                          add_legend=True, crop_from_sides_px=0, draw_inner_circle_r=-1, draw_outer_circle_r=-1,
                          frames_per_second=20, add_scale=True, movement_series_list=None, add_tip_position=False)

# %%
_, _, rasterized_maps = load_data_from_pickle("/cs/usr/roi.eliasian/LabFolder/NpcTransportExperiment/HS-AFM-Dataset/dataset/afm/new/mini_200uM_100ns_40x40/10.pickle")
im = output_image.output_image(rasterized_maps[0], "", 40, 65, 1000, 1000, "jet", add_legend=True,
             crop_from_sides_px=0, draw_inner_circle_r=11, draw_outer_circle_r=18.5, add_scale=True, save=False)
display(im)

_, _, rasterized_maps = load_data_from_pickle("/cs/usr/roi.eliasian/LabFolder/NpcTransportExperiment/HS-AFM-Dataset/dataset/afm/new/mini_200uM_10ns_40x40/10.pickle")
im = output_image.output_image(rasterized_maps[0], "", 40, 65, 1000, 1000, "jet", add_legend=True,
             crop_from_sides_px=0, draw_inner_circle_r=11, draw_outer_circle_r=18.5, add_scale=True, save=False)
display(im)

# %%
for i in range(20, 25):
    _, _, rasterized_maps = load_data_from_pickle(f"/cs/usr/roi.eliasian/LabFolder/NpcTransportExperiment/HS-AFM-Dataset/dataset/afm/new/mini_0uM_10ns_40x40/{i}.pickle")
    im = output_image.output_image(rasterized_maps[0], "", 40, 65, 1000, 1000, "jet", add_legend=True,
                crop_from_sides_px=0, draw_inner_circle_r=11, draw_outer_circle_r=18.5, add_scale=True, save=False)
    display(im)
# Out:
# <PIL.Image.Image image mode=RGB size=1337x1000>
# <PIL.Image.Image image mode=RGB size=1337x1000>
# <PIL.Image.Image image mode=RGB size=1337x1000>
# <PIL.Image.Image image mode=RGB size=1337x1000>
# <PIL.Image.Image image mode=RGB size=1337x1000>

# %%
for i in range(20, 25):
    _, _, rasterized_maps = load_data_from_pickle(f"/cs/usr/roi.eliasian/LabFolder/NpcTransportExperiment/HS-AFM-Dataset/dataset/afm/new/mini_0uM_100ns_40x40/{i}.pickle")
    im = output_image.output_image(rasterized_maps[0], "", 40, 65, 1000, 1000, "jet", add_legend=True,
                crop_from_sides_px=0, draw_inner_circle_r=11, draw_outer_circle_r=18.5, add_scale=True, save=False)
    display(im)
# Out:
# <PIL.Image.Image image mode=RGB size=1337x1000>
# <PIL.Image.Image image mode=RGB size=1337x1000>
# <PIL.Image.Image image mode=RGB size=1337x1000>
# <PIL.Image.Image image mode=RGB size=1337x1000>
# <PIL.Image.Image image mode=RGB size=1337x1000>

# %%
_, _, rasterized_maps = load_data_from_pickle("/cs/usr/roi.eliasian/LabFolder/NpcTransportExperiment/HS-AFM-Dataset/dataset/afm/new/full_50uM_1ns/3.pickle")
im = output_image.output_image(rasterized_maps[0], "", 40, 65, 1000, 1000, "jet", add_legend=True,
             crop_from_sides_px=0, draw_inner_circle_r=39, draw_outer_circle_r=54, add_scale=True, save=False)
display(im)

_, _, rasterized_maps = load_data_from_pickle("/cs/usr/roi.eliasian/LabFolder/NpcTransportExperiment/HS-AFM-Dataset/dataset/afm/new/full_0uM_1ns/3.pickle")
im = output_image.output_image(rasterized_maps[0], "", 40, 65, 1000, 1000, "jet", add_legend=True,
             crop_from_sides_px=0, draw_inner_circle_r=39, draw_outer_circle_r=54, add_scale=True, save=False)
display(im)
# Out:
# <PIL.Image.Image image mode=RGB size=1337x1000>
# <PIL.Image.Image image mode=RGB size=1337x1000>

# %%
_, non_rasterized_maps, rasterized_maps = load_data_from_pickle("/cs/usr/roi.eliasian/LabFolder/NpcTransportExperiment/HS-AFM-Dataset/dataset/afm/new/full_50uM_1ns/3.pickle")

# %%
im = output_image.output_image(non_rasterized_maps[90], "", 40, 65, 1000, 1000, "jet", add_legend=True,
             crop_from_sides_px=0, draw_inner_circle_r=39, draw_outer_circle_r=54, add_scale=True, save=False)
display(im)
# Out:
# <PIL.Image.Image image mode=RGB size=1337x1000>
